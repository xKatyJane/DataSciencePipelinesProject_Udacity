# %% [markdown]
# # Pipeline Project

# %% [markdown]
# You will be using the provided data to create a machine learning model pipeline.
#
# You must handle the data appropriately in your pipeline to predict whether an
# item is recommended by a customer based on their review.
# Note the data includes numerical, categorical, and text data.
#
# You should ensure you properly train and evaluate your model.

# %% [markdown]
# ## The Data

# %% [markdown]
# The dataset has been anonymized and cleaned of missing values.
#
# There are 8 features for to use to predict whether a customer recommends or does
# not recommend a product.
# The `Recommended IND` column gives whether a customer recommends the product
# where `1` is recommended and a `0` is not recommended.
# This is your model's target/

# %% [markdown]
# The features can be summarized as the following:
#
# - **Clothing ID**: Integer Categorical variable that refers to the specific piece being reviewed.
# - **Age**: Positive Integer variable of the reviewers age.
# - **Title**: String variable for the title of the review.
# - **Review Text**: String variable for the review body.
# - **Positive Feedback Count**: Positive Integer documenting the number of other customers who found this review positive.
# - **Division Name**: Categorical name of the product high level division.
# - **Department Name**: Categorical name of the product department name.
# - **Class Name**: Categorical name of the product class name.
#
# The target:
# - **Recommended IND**: Binary variable stating where the customer recommends the product where 1 is recommended, 0 is not recommended.

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, accuracy_score
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import FunctionTransformer
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# %% [markdown]
# ## Load Data

# %%
# Load data
df = pd.read_csv(
    'data/reviews.csv',
)

df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18442 entries, 0 to 18441
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Clothing ID              18442 non-null  int64
#  1   Age                      18442 non-null  int64
#  2   Title                    18442 non-null  object
#  3   Review Text              18442 non-null  object
#  4   Positive Feedback Count  18442 non-null  int64
#  5   Division Name            18442 non-null  object
#  6   Department Name          18442 non-null  object
#  7   Class Name               18442 non-null  object
#  8   Recommended IND          18442 non-null  int64
# dtypes: int64(4), object(5)
# memory usage: 1.3+ MB
#    Clothing ID  Age                    Title  \
# 0         1077   60  Some major design flaws
# 1         1049   50         My favorite buy!
# 2          847   47         Flattering shirt
# ...

# %%
df.isnull().sum()
# Out:
# Clothing ID                0
# Age                        0
# Title                      0
# Review Text                0
# Positive Feedback Count    0
# Division Name              0
# Department Name            0
# Class Name                 0
# Recommended IND            0
# dtype: int64

# %% [markdown]
# ## Preparing features (`X`) & target (`y`)

# %%
data = df

# separate features from labels
X = data.drop('Recommended IND', axis=1)
y = data['Recommended IND'].copy()

print('Labels:', y.unique())
print('Features:')
display(X.head())
# Out:
# Labels: [0 1]
# Features:
#    Clothing ID  Age                    Title  \
# 0         1077   60  Some major design flaws
# 1         1049   50         My favorite buy!
# 2          847   47         Flattering shirt
# 3         1080   49  Not for the very petite
# 4          858   39     Cagrcoal shimmer fun
#
#                                          Review Text  Positive Feedback Count  \
# 0  I had such high hopes for this dress and reall...                        0
# 1  I love, love, love this jumpsuit. it's fun, fl...                        0
# 2  This shirt is very flattering to all due to th...                        6
# 3  I love tracy reese dresses, but this one is no...                        4
# 4  I aded this in my basket at hte last mintue to...                        1
#
#     Division Name Department Name Class Name
# 0         General         Dresses    Dresses
# 1  General Petite         Bottoms      Pants
# 2         General            Tops    Blouses
# ...

# %% [markdown]
# ## Defining the training and test values

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.1,
    shuffle=True,
    random_state=27,
)

# %% [markdown]
# ## Data Exploration

# %%
data.isnull().sum()
# Out:
# Clothing ID                0
# Age                        0
# Title                      0
# Review Text                0
# Positive Feedback Count    0
# Division Name              0
# Department Name            0
# Class Name                 0
# Recommended IND            0
# dtype: int64

# %%
data['Recommended IND'].value_counts()
# Out:
# Recommended IND
# 1    15053
# 0     3389
# Name: count, dtype: int64

# %% [markdown]
# ## Building Pipeline

# %% [markdown]
# ### Defining feature types and processing them

# %%
numerical_features = ['Age', 'Positive Feedback Count']
categorical_features = ['Division Name', 'Department Name', 'Class Name']

df['Combined Text Features'] = df['Title'] + " " + df['Review Text']
text_features = ['Combined Text Features']
df.head()
# Out:
#    Clothing ID  Age                    Title  \
# 0         1077   60  Some major design flaws
# 1         1049   50         My favorite buy!
# 2          847   47         Flattering shirt
# 3         1080   49  Not for the very petite
# 4          858   39     Cagrcoal shimmer fun
#
#                                          Review Text  Positive Feedback Count  \
# 0  I had such high hopes for this dress and reall...                        0
# 1  I love, love, love this jumpsuit. it's fun, fl...                        0
# 2  This shirt is very flattering to all due to th...                        6
# 3  I love tracy reese dresses, but this one is no...                        4
# 4  I aded this in my basket at hte last mintue to...                        1
#
#     Division Name Department Name Class Name  Recommended IND  \
# 0         General         Dresses    Dresses                0
# 1  General Petite         Bottoms      Pants                1
# ...

# %%
combine_text = FunctionTransformer(lambda X: (X['Title'] + " " + X['Review Text']), validate=False)

preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_features),
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features),
        ('text', Pipeline([
            ('combine', combine_text),
            ('tfidf', TfidfVectorizer(max_features=5000))
        ]), ['Title', 'Review Text'])
    ]
)

# %% [markdown]
# ### Comparing models

# %%
# Pipeline 1: XGBClassifier
pipeline_xgb = Pipeline([
    ('preprocessor', preprocessor),
    ('classifier', XGBClassifier(
        n_estimators=200,
        max_depth=6,
        learning_rate=0.1,
        random_state=27,
        eval_metric='logloss'
    ))
])

# Pipeline 2: Random Forest
pipeline_rf = Pipeline([
    ('preprocessor', preprocessor),
    ('classifier', RandomForestClassifier(
        n_estimators=200,
        max_depth=6,
        random_state=27
    ))
])

# %% [markdown]
# ## Training Pipelines

# %% [markdown]
# #### XGBClassifier Pipeline

# %%
pipeline_xgb.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['Age',
#                                                    'Positive Feedback Count']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Division Name',
#                                                    'Department Name',
#                                                    'Class Name']),
#                                                  ('text',
#                                                   Pipeline(steps=[('combine',
#                                                                    FunctionTransformer(func=<function <lambda> at 0x1451e1120>)),
#                                                                   ('tfidf',
# ...

# %% [markdown]
# #### RandomForestClassifier Pipeline

# %%
pipeline_rf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['Age',
#                                                    'Positive Feedback Count']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Division Name',
#                                                    'Department Name',
#                                                    'Class Name']),
#                                                  ('text',
#                                                   Pipeline(steps=[('combine',
#                                                                    FunctionTransformer(func=<function <lambda> at 0x1451e1120>)),
#                                                                   ('tfidf',
# ...

# %% [markdown]
# #### Comparing accuracy

# %%
print("XGBClassifier accuracy:", f"{pipeline_xgb.score(X_test, y_test):.3f}")
print("RandomForestClassifier accuracy:", f"{pipeline_rf.score(X_test, y_test):.3f}")
# Out:
# XGBClassifier accuracy: 0.885
# RandomForestClassifier accuracy: 0.823

# %% [markdown]
# XGBClassifier accuracy is much higher, so I am fine tuning this model.

# %%
xgb_param_dist = {
    'classifier__n_estimators': [100, 200, 300],
    'classifier__max_depth': [4, 6, 8],
    'classifier__learning_rate': [0.01, 0.1, 0.2],
    'classifier__subsample': [0.8, 1.0]
}

random_xgb = RandomizedSearchCV(
    pipeline_xgb,
    param_distributions=xgb_param_dist,
    n_iter=15,
    cv=3,
    scoring='accuracy',
    n_jobs=-1,
    verbose=2,
    random_state=27
)

random_xgb.fit(X_train, y_train)

print("Best XGB params:", random_xgb.best_params_)
print("Best XGB score:", f"{random_xgb.best_score_:.3f}")
# Out:
# Fitting 3 folds for each of 15 candidates, totalling 45 fits
# Best XGB params: {'classifier__subsample': 1.0, 'classifier__n_estimators': 300, 'classifier__max_depth': 6, 'classifier__learning_rate': 0.2}
# Best XGB score: 0.894

# %% [markdown]
# #### By running the RandomizedS
